# %% [markdown]
# <a href="https://colab.research.google.com/github/hardikrajb/chronic-kidney-disease-detection/blob/main/internship(dv).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("/content/Main_file.csv")
d = pd.read_csv("/content/Merged_Data_2.csv")
df.head()
print(d.columns)
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Pid', 'Age', 'Gender', 'Race/Ethnicity', 'BMI', 'BP',
#        'Diabetes', 'Hypertension', 'Cardiovascular Disease', 'Smoking History',
#        'Family History of Kidney Disease', 'Previous Kidney Disease Diagnosis',
#        'Medications', 'Albumin to Creatinine Ratio',
#        'Glomerular Filtration Rate', 'Serum Creatinine Level',
#        'Hemoglobin Level', 'Serum Calcium Level', 'Serum Phosphate Level',
#        'Serum Potassium Level', 'Serum Sodium Level', 'Serum Albumin Level',
#        'Serum Bicarbonate Level', 'Urinary Tract Infections', 'Kidney Stones',
#        'History of Kidney Injury', 'Urine Output per Day',
#        'Other Medical Conditions', 'stage', 'group', 'previous_stage', 'Med_A',
#        'Med_B', 'Med_C', 'Med_D', 'Med_E', 'BP_Range'],
#       dtype='object')
# Index(['Unnamed: 0', 'Age', 'BMI', 'Diabetes', 'Hypertension',
#        'Albumin to Creatinine Ratio', 'Glomerular Filtration Rate',
# ...

# %%
df1 = pd.DataFrame(df[['Albumin to Creatinine Ratio','Serum Creatinine Level','Glomerular Filtration Rate','Hemoglobin Level', 'Serum Calcium Level', 'Serum Phosphate Level','Serum Potassium Level', 'Serum Sodium Level', 'Serum Albumin Level','Med_1','Med_2','Med_3','Med_4','Med_5','Stage','group']],columns=['Albumin to Creatinine Ratio','Serum Creatinine Level','Glomerular Filtration Rate','Hemoglobin Level', 'Serum Calcium Level', 'Serum Phosphate Level','Serum Potassium Level', 'Serum Sodium Level', 'Serum Albumin Level','Med_1','Med_2','Med_3','Med_4','Med_5','Stage','group'])

# %%
df1.columns
# Out:
# Index(['Albumin to Creatinine Ratio', 'Serum Creatinine Level',
#        'Glomerular Filtration Rate', 'Hemoglobin Level', 'Serum Calcium Level',
#        'Serum Phosphate Level', 'Serum Potassium Level', 'Serum Sodium Level',
#        'Serum Albumin Level', 'Med_1', 'Med_2', 'Med_3', 'Med_4', 'Med_5',
#        'Stage', 'group'],
#       dtype='object')

# %%
df1.shape
# Out:
# (4996, 16)

# %%
df1.head()
# Out:
#    Albumin to Creatinine Ratio  Serum Creatinine Level  \
# 0                        174.6                     3.2
# 1                        298.7                     3.2
# 2                        208.0                     3.2
# 3                        256.9                     3.7
# 4                         28.8                     8.0
#
#    Glomerular Filtration Rate  Hemoglobin Level  Serum Calcium Level  \
# 0                        21.0               8.2                  7.3
# 1                        16.7               8.4                  7.1
# 2                        17.3               7.0                  7.9
# 3                        15.1               8.3                  7.8
# 4                        13.1               6.6                  6.8
#
#    Serum Phosphate Level  Serum Potassium Level  Serum Sodium Level  \
# 0                    6.3                    5.3                 145
# 1                    4.9                    5.9                 146
# ...

# %%
y = df['group']
df['group'].value_counts()
# Out:
# 1    2500
# 0    2496
# Name: group, dtype: int64

# %%
'''from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y = encoder.fit_transform(y)
y'''
# Out:
# 'from sklearn.preprocessing import LabelEncoder\nencoder = LabelEncoder()\ny = encoder.fit_transform(y)\ny'

# %%
import seaborn as sns

# %%
g = sns.PairGrid(df1,vars=[ 'Med_1', 'Med_2', 'Med_3', 'Med_4', 'Med_5',
       'Stage'],hue='group',palette='RdBu_r')
g.map(plt.scatter,alpha=0.8)
g.add_legend();

# %%
plt.scatter(df1['Med_1'],df1['Stage'],c=df1['group'],cmap='coolwarm')
plt.xlabel("med_1")
plt.ylabel('stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.gcf().set_facecolor('lightgray')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(df1['Med_2'],df1['Stage'],c=df1['group'],cmap='coolwarm')
plt.xlabel("med_2")
plt.ylabel('stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.gcf().set_facecolor('lightgray')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(df1['Med_3'],df1['Stage'],c=df1['group'],cmap='PuRd')
plt.xlabel("med_3")
plt.ylabel('stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.gcf().set_facecolor('lightgray')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(df1['Med_4'],df1['Stage'],c=df1['group'],cmap='RdBu_r')
plt.xlabel("med_4")
plt.ylabel('stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.gcf().set_facecolor('lightgray')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(df1['Med_5'],df1['Stage'],c=df1['group'],cmap='RdBu_r')
plt.xlabel("med_5")
plt.ylabel('stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.gcf().set_facecolor('lightgray')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
'''g = sns.PairGrid(d,vars=['Albumin to Creatinine Ratio', 'Serum Creatinine Level',
       'Glomerular Filtration Rate', 'Hemoglobin Level', 'Serum Calcium Level',
       'Serum Phosphate Level', 'Serum Potassium Level', 'Serum Sodium Level',
       'Serum Albumin Level','previous_stage'],hue='group',palette='RdBu_r')
g.map(plt.scatter,alpha=0.8)
g.add_legend();'''
# Out:
# "g = sns.PairGrid(d,vars=['Albumin to Creatinine Ratio', 'Serum Creatinine Level',\n       'Glomerular Filtration Rate', 'Hemoglobin Level', 'Serum Calcium Level',\n       'Serum Phosphate Level', 'Serum Potassium Level', 'Serum Sodium Level',\n       'Serum Albumin Level','previous_stage'],hue='group',palette='RdBu_r')\ng.map(plt.scatter,alpha=0.8)\ng.add_legend();"

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
print(d['group'].value_counts())
d['group'] = encoder.fit_transform(d['group'])
print(d['group'].value_counts())
# Out:
# Stable         3289
# Progression     950
# Regression      757
# Name: group, dtype: int64
# 2    3289
# 0     950
# 1     757
# Name: group, dtype: int64

# %% [markdown]
# from above we can say that
#
# 2 - Stable(red)
#
# 0 - Progression(blue)
#
# 1 - Regression(gray)

# %%
plt.scatter(d['Albumin to Creatinine Ratio'],d['previous_stage'],c=d['group'],cmap='coolwarm')
plt.xlabel('Albumin to Creatinine Ratio')
plt.ylabel('previous_stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.gcf().set_facecolor('lightgray')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(d['Serum Creatinine Level'],d['previous_stage'],c=d['group'],cmap='coolwarm')
plt.xlabel('Serum Creatinine Level')
plt.ylabel('previous_stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(d['Glomerular Filtration Rate'],d['previous_stage'],c=d['group'],cmap='coolwarm')
plt.xlabel('Glomerular Filtration Rate')
plt.ylabel('previous_stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(d['Hemoglobin Level'],d['previous_stage'],c=d['group'],cmap='coolwarm')
plt.xlabel('Hemoglobin Level')
plt.ylabel('previous_stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(d['Serum Phosphate Level'],d['previous_stage'],c=d['group'],cmap='coolwarm')
plt.xlabel('Serum Phosphate Level')
plt.ylabel('previous_stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(d['Serum Calcium Level'],d['previous_stage'],c=d['group'],cmap='coolwarm')
plt.xlabel('Serum calcium Level')
plt.ylabel('previous_stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(d['Serum Potassium Level'],d['previous_stage'],c=d['group'],cmap='coolwarm')
plt.xlabel('Serum Potassium Level')
plt.ylabel('previous_stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(d['Serum Sodium Level'],d['previous_stage'],c=d['group'],cmap='coolwarm')
plt.xlabel('Serum Sodium Level')
plt.ylabel('previous_stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(d['Serum Albumin Level'],d['previous_stage'],c=d['group'],cmap='coolwarm')
plt.xlabel('Serum Albumin Level')
plt.ylabel('previous_stage')
cbar = plt.colorbar()
cbar.set_label('group')
plt.legend();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
